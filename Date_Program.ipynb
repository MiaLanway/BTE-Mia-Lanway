# %% [markdown]
# <a href="https://colab.research.google.com/github/MiaLanway/BTE-Mia-Lanway/blob/main/Date_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
input_date = input("Enter date in format MM/DD/YYYY")
month = input_date[ :2]
print(month)
day = input_date[3:5]
print(day)
year = input_date[6: ]
print(year)
# Out:
# Enter date in format MM/DD/YYYY12/15/2003
# 12
# 15
# 2003
